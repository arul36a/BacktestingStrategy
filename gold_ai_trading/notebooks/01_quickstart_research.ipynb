# %% [markdown]
# # GOLD AI — Quickstart Notebook
#
# - Download cached OHLCV data
# - Build engineered features
# - Launch a toy VectorBT parameter sweep
#
# Run notebooks from repo root (`gold_ai_trading/`) so `src` resolves.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if ROOT.name != "gold_ai_trading":
    sys.path.insert(0, str(ROOT / "gold_ai_trading"))

from src.utils import load_app_config
from src.data_loader import GoldDataLoader
from src.feature_engineering import FeaturePipeline

cfg = load_app_config()
loader = GoldDataLoader(cfg)
df = loader.download(interval="1d", use_cache=True)
feat = FeaturePipeline(cfg).transform(df)
feat.tail()
